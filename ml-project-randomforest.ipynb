# %%
import os
import cv2
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle

# LOADING DATA & PREPARATION

train_csv_path = "/kaggle/input/UBC-OCEAN/train.csv"
train_images_path = "/kaggle/input/UBC-OCEAN/train_thumbnails"
test_csv_path = "/kaggle/input/UBC-OCEAN/test.csv"
test_images_path = "/kaggle/input/UBC-OCEAN/test_images"
submission_path = "/kaggle/working/submission.csv"

train_df = pd.read_csv(train_csv_path)
test_df = pd.read_csv(test_csv_path)


# Working on only thumbnails 
existing_images = set(img.split('_')[0] for img in os.listdir(train_images_path))
print( len(existing_images))
train_df['image_id'] = train_df['image_id'].astype(str)
print(train_df.count())
train_df = train_df[train_df['image_id'].isin(existing_images)]
print(train_df.count())

labels = train_df['label']
encoder = LabelEncoder()
encoded_labels = encoder.fit_transform(labels)
train_df['encoded_labels'] = encoded_labels

def preprocess_image(image_path, target_size=(128, 128)):
    if os.path.exists(image_path):
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = cv2.resize(image, target_size)
        image = image / 255.0  # Normalize pixel values to [0, 1]
        print(f"LOG: prepricesing img {image_path}")
        return image
    else:
        return None

train_df['image_id'] = train_df['image_id'].astype(str)

train_images = []
train_labels = []
for img_id in train_df['image_id']:
    img_path = os.path.join(train_images_path, f"{img_id}_thumbnail.png")
    image = preprocess_image(img_path)
    if image is not None:
        train_images.append(image)
        train_labels.append(train_df[train_df['image_id'] == img_id]['encoded_labels'].values[0])

train_images = np.array(train_images)
train_labels = np.array(train_labels)

train_images, train_labels = shuffle(train_images, train_labels, random_state=42)

train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)

train_images_flatten = train_images.reshape(train_images.shape[0], -1)
val_images_flatten = val_images.reshape(val_images.shape[0], -1)

# MODEL

model = RandomForestClassifier(n_estimators=100, random_state=42)

print("FITTING THE MODEL")
model.fit(train_images_flatten, train_labels)
val_predictions = model.predict(val_images_flatten)

# Accuracy
accuracy = accuracy_score(val_labels, val_predictions)
print(f"Validation Accuracy: {accuracy}")
# Out:
# 513
# image_id        538
# label           538
# image_width     538
# image_height    538
# is_tma          538
# dtype: int64
# image_id        513
# label           513
# image_width     513
# image_height    513
# is_tma          513
# dtype: int64
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/4_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/66_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/281_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/286_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/431_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/706_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/970_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/1020_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/1080_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/1101_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/1252_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/1289_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/1295_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/1660_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/1666_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/1774_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/1925_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/1943_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/1952_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/2097_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/2227_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/2391_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/2666_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/2706_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/2906_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/3055_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/3084_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/3092_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/3098_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/3191_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/3222_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/3264_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/3511_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/3672_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/3881_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/3997_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/4211_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/4608_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/4797_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/4827_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/4877_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/4963_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/5015_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/5114_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/5251_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/5264_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/5265_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/5307_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/5456_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/5851_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/5852_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/5970_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/5992_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/6140_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/6175_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/6281_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/6359_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/6363_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/6449_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/6558_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/6582_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/6793_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/6843_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/6898_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/6951_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/7204_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/7329_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/7482_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/7490_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/7955_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/8130_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/8213_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/8240_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/8279_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/8531_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/8713_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/8805_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/8985_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/9154_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/9183_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/9254_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/9341_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/9509_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/9658_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/9697_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/10077_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/10143_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/10246_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/10252_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/10469_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/10548_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/10642_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/10800_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/10896_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/11263_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/11417_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/11431_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/11557_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/11559_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/12159_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/12222_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/12244_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/12442_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/12522_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/12902_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/13364_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/13387_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/13526_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/13987_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/14039_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/14051_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/14127_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/14312_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/14401_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/14424_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/14532_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/14542_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/14617_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/15139_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/15188_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/15209_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/15221_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/15231_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/15293_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/15470_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/15486_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/15583_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/15671_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/15742_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/15871_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/15912_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/16042_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/16064_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/16209_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/16325_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/16494_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/16876_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/16986_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/17067_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/17174_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/17291_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/17365_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/17416_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/17487_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/17738_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/17854_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/18014_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/18138_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/18196_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/18547_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/18568_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/18607_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/18810_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/18813_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/18896_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/18914_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/18981_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/19030_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/19157_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/19255_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/19512_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/19569_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/20205_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/20312_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/20316_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/20329_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/20463_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/20670_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/20858_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/20882_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/21232_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/21260_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/21303_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/21373_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/21432_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/21445_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/21910_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/21929_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/22155_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/22221_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/22290_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/22425_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/22489_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/22654_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/22740_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/22924_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/23523_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/23629_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/23796_thumbnail.png
# LOG: prepricesing img /kaggle/input/UBC-OCEAN/train_thumbnails/